# %%
import skimage.io as io
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
mandrill = io.imread('mandrill.jpg')

# %%
io.imshow(mandrill) #shows you the image in question

# %%
import matplotlib.pyplot as plt
import numpy as np

def show_images(images,titles=None):
    """Display a list of images"""
    n_ims = len(images)
    if titles is None: titles = ['(%d)' % i for i in range(1,n_ims + 1)]
    fig = plt.figure()
    n = 1
    for image,title in zip(images,titles):
        a = fig.add_subplot(1,n_ims,n) # Make subplot
        if image.ndim == 2: # Is image grayscale?
            plt.gray() # Only place in this blog you can't replace 'gray' with 'grey'
        plt.imshow(image)
        a.set_title(title)
        n += 1
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_ims)
    plt.show()

# %%
# Create an image (10 x 10 pixels)
rgb_image = np.zeros(shape=(10,10,3),dtype=np.uint8) # <- unsigned 8 bit int

rgb_image[:,:,0] = 255 # Set red value for all pixels
rgb_image[:,:,1] = 255 # Set green value for all pixels
rgb_image[:,:,2] = 0   # Set blue value for all pixels

show_images(images=[rgb_image],titles=["Red plus Green equals..."])

# %%
red, green, blue = image.copy(), image.copy(), image.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-28f4a88b84e9> in <module>()
# ----> 1 red, green, blue = image.copy(), image.copy(), image.copy()
#
# NameError: name 'image' is not defined

# %%
show_images(images=[red, green, blue], titles=['Red Intensity', 'Green Intensity', 'Blue Intensity'])

print ('Note: lighter areas correspond to higher intensities\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6f829fcf7652> in <module>()
# ----> 1 show_images(images=[red, green, blue], titles=['Red Intensity', 'Green Intensity', 'Blue Intensity'])
#       2
#       3 print ('Note: lighter areas correspond to higher intensities\n')
#
# NameError: name 'red' is not defined
